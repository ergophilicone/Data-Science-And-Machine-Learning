# %% [markdown]
# ### Variable Assignment : A variable can be created using =, which is called the assignment operator.
#
# * A python variable is need not to declare before assignning it.
# * A python variable is need not to refered as any type of value we are going to use it in.

# %%
spam_amount = 0

# %%
print(spam_amount)
# Out:
# 0

# %% [markdown]
# ### Function Calls: Functions are called by putting parentheses after their name, and putting the inputs(or arguments) to the functions in those parentheses
#
# * In Python, comments begin with the # symbol
#
# ### Reassigning the values of an existing variable looks just the same as creating a variable - it still uses the = assignment operator.

# %%
spam_amount = spam_amount + 4

# %%
if spam_amount > 0:
    print("But I dont want any spams!")

viking_song = "Spam Spam Spam"
print(viking_song)
# Out:
# But I dont want any spams!
# Spam Spam Spam

# %% [markdown]
# ### This code snippet is also our first sighting of a string in Python:
#
# "But I don't want ANY spam!"
#
# ### Strings can be marked either by double or single quotation marks. (But because this particular string contains a single-quote character, we might confuse Python by trying to surround it with single-quotes, unless we're careful.)

# %%
viking_song = "Spam " * spam_amount
print(viking_song)
# Out:
# Spam Spam Spam Spam

# %% [markdown]
# ### Numbers and Arithmetic In Python

# %% [markdown]
# * int - short for integer
# * float - number with a decimal place
#
# type() | Returns data type of anything in Python

# %% [markdown]
# A natural thing to want to do with numbers is perform arithmetic. We've seen the + operator for addition, and the * operator for multiplication. Python also has us covered for the rest of the basic buttons on your calculator:
# ![image.png](attachment:image.png)
#
# One interesting observation here is that, whereas your calculator probably just has one button for division, Python can do two kinds. "True division" is basically what your calculator does:

# %%
print(5/2, 6/2)
# Out:
# 2.5 3.0

# %% [markdown]
# It always gives us a float.
#
# The // operator gives us a result that's rounded down to the next integer.

# %%
print(5//2, 6//2)
# Out:
# 2 3

# %% [markdown]
# ### Order Of Operation
#
# The arithmetic we learned in primary school has conventions about the order in which operations are evaluated. Some remember these by a mnemonic such as PEMDAS - Parentheses, Exponents, Multiplication/Division, Addition/Subtraction.
#
# Python follows similar rules about which calculations to perform first. They're mostly pretty intuitive.

# %%
8 - 3 + 2
# Out:
# 7

# %%
-3 + 4*2
# Out:
# 5

# %%
print(min(1, 2, 3))
print(max(1, 2, 3))
print(float(10))
print(int(3.33))
# They can even be called on strings!
print(int('807') + 1)
# Out:
# 1
# 3
# 10.0
# 3
# 808
